# %%
from get_data import data_prep

# %%
data_prep.download_data(["069500.KS", "229200.KS",
             "133690.KS", "143850.KS",
             "114260.KS", "153130.KS",
             "157450.KS"
             ]
,'2000-01-01', '2022-12-31','1d')
# Out:
# [*********************100%%**********************]  7 of 7 completed
# Price          Adj Close                                              \
# Ticker         069500.KS 114260.KS     133690.KS 143850.KS 153130.KS
# Date
# 2007-01-29  13827.810547       NaN           NaN       NaN       NaN
# 2007-01-30  13881.470703       NaN           NaN       NaN       NaN
# 2007-01-31  13808.642578       NaN           NaN       NaN       NaN
# 2007-02-01  14007.931641       NaN           NaN       NaN       NaN
# 2007-02-02  14306.875000       NaN           NaN       NaN       NaN
# ...                  ...       ...           ...       ...       ...
# 2022-12-23  29224.820312   56600.0  62387.347656   44400.0  104420.0
# 2022-12-26  29268.318359   56570.0  62288.078125   44680.0  104420.0
# 2022-12-27  29476.136719   56490.0  62466.765625   44915.0  104420.0
# 2022-12-28  29128.162109   56425.0  61052.144531   44500.0  104475.0
# ...
